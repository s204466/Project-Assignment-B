# %% [markdown]
# intro text

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

data95 = pd.read_csv("../1995_Street_Tree_Census.csv", low_memory=False)
data05 = pd.read_csv("../2005_Street_Tree_Census.csv", low_memory=False)
data15 = pd.read_csv("../2015_Street_Tree_Census.csv", low_memory=False)
# Out:
#    RecordId        Address  House_Number      Street  Postcode_Original  \
# 0         1    245 E 17 ST         245.0     E 17 ST              10003
# 1         2  80 N MOORE ST          80.0  N MOORE ST              10013
# 2         3  80 N MOORE ST          80.0  N MOORE ST              10013
# 3         4  80 N MOORE ST          80.0  N MOORE ST              10013
# 4         5  80 N MOORE ST          80.0  N MOORE ST              10013
#
#    Community Board_Original   Site Species  Diameter  Condition  ...  \
# 0                       106  Front    PLAC         8    Unknown  ...
# 1                       101   Side    ACPL         7       Good  ...
# 2                       101   Side    ACPL         6       Good  ...
# 3                       101   Side    ACPL         7  Excellent  ...
# 4                       101   Side    ACPL         6       Good  ...
#
#              Spc_Latin                 Location Council District        BIN  \
# 0  PLATANUS ACERIFOLIA  (40.734551, -73.984235)              2.0  1019566.0
# 1     ACER PLATANOIDES  (40.720159, -74.010532)              1.0  1083157.0
# 2     ACER PLATANOIDES  (40.720159, -74.010532)              1.0  1083157.0
# 3     ACER PLATANOIDES  (40.720159, -74.010532)              1.0  1083157.0
# 4     ACER PLATANOIDES  (40.720159, -74.010532)              1.0  1083157.0
#
#             BBL  Zip Codes  Community Districts  Borough Boundaries  \
# 0  1.008980e+09    11724.0                 71.0                 4.0
# 1  1.001420e+09    12076.0                 56.0                 4.0
# 2  1.001420e+09    12076.0                 56.0                 4.0
# 3  1.001420e+09    12076.0                 56.0                 4.0
# 4  1.001420e+09    12076.0                 56.0                 4.0
#
#    City Council Districts  Police Precincts
# 0                    50.0               7.0
# 1                    32.0               1.0
# 2                    32.0               1.0
# 3                    32.0               1.0
# 4                    32.0               1.0
#
# [5 rows x 35 columns]

# %%
data95
# Out:
#         RecordId          Address  House_Number        Street  \
# 0              1      245 E 17 ST         245.0       E 17 ST
# 1              2    80 N MOORE ST          80.0    N MOORE ST
# 2              3    80 N MOORE ST          80.0    N MOORE ST
# 3              4    80 N MOORE ST          80.0    N MOORE ST
# 4              5    80 N MOORE ST          80.0    N MOORE ST
# ...          ...              ...           ...           ...
# 516984    516787  36 WINDHAM LOOP          36.0  WINDHAM LOOP
# 516985    516788  36 WINDHAM LOOP          36.0  WINDHAM LOOP
# 516986    516966   44 WESTPORT ST          44.0   WESTPORT ST
# 516987    516967   44 WESTPORT ST          44.0   WESTPORT ST
# 516988    516968   44 WESTPORT ST          44.0   WESTPORT ST
#
#         Postcode_Original  Community Board_Original   Site Species  Diameter  \
# 0                   10003                       106  Front    PLAC         8
# 1                   10013                       101   Side    ACPL         7
# 2                   10013                       101   Side    ACPL         6
# 3                   10013                       101   Side    ACPL         7
# 4                   10013                       101   Side    ACPL         6
# ...                   ...                       ...    ...     ...       ...
# 516984              10314                       502   Side    PYCA         3
# 516985              10314                       502   Side    PYCA         3
# 516986              10314                       502   Side    PYCA         4
# 516987              10314                       502   Side    PYCA         4
# 516988              10314                       502   Side    PYCA         4
#
#         Condition  ...            Spc_Latin                 Location  \
# 0         Unknown  ...  PLATANUS ACERIFOLIA  (40.734551, -73.984235)
# 1            Good  ...     ACER PLATANOIDES  (40.720159, -74.010532)
# 2            Good  ...     ACER PLATANOIDES  (40.720159, -74.010532)
# 3       Excellent  ...     ACER PLATANOIDES  (40.720159, -74.010532)
# 4            Good  ...     ACER PLATANOIDES  (40.720159, -74.010532)
# ...           ...  ...                  ...                      ...
# 516984       Good  ...     PYRUS CALLERYANA               (1.0, 1.0)
# 516985       Good  ...     PYRUS CALLERYANA               (1.0, 1.0)
# 516986       Good  ...     PYRUS CALLERYANA  (40.583648, -74.159767)
# 516987       Good  ...     PYRUS CALLERYANA  (40.583648, -74.159767)
# 516988       Good  ...     PYRUS CALLERYANA  (40.583648, -74.159767)
#
#        Council District        BIN           BBL  Zip Codes  \
# 0                   2.0  1019566.0  1.008980e+09    11724.0
# 1                   1.0  1083157.0  1.001420e+09    12076.0
# 2                   1.0  1083157.0  1.001420e+09    12076.0
# 3                   1.0  1083157.0  1.001420e+09    12076.0
# 4                   1.0  1083157.0  1.001420e+09    12076.0
# ...                 ...        ...           ...        ...
# 516984              NaN        NaN           NaN        NaN
# 516985              NaN        NaN           NaN        NaN
# 516986              NaN        NaN           NaN    10700.0
# 516987              NaN        NaN           NaN    10700.0
# 516988              NaN        NaN           NaN    10700.0
#
#         Community Districts  Borough Boundaries  City Council Districts  \
# 0                      71.0                 4.0                    50.0
# 1                      56.0                 4.0                    32.0
# 2                      56.0                 4.0                    32.0
# 3                      56.0                 4.0                    32.0
# 4                      56.0                 4.0                    32.0
# ...                     ...                 ...                     ...
# 516984                  NaN                 NaN                     NaN
# 516985                  NaN                 NaN                     NaN
# 516986                 30.0                 1.0                     9.0
# 516987                 30.0                 1.0                     9.0
# 516988                 30.0                 1.0                     9.0
#
#         Police Precincts
# 0                    7.0
# 1                    1.0
# 2                    1.0
# 3                    1.0
# 4                    1.0
# ...                  ...
# 516984               NaN
# 516985               NaN
# 516986              75.0
# 516987              75.0
# 516988              75.0
#
# [516989 rows x 35 columns]
