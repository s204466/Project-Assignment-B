# %% [markdown]
# # Exercise 1
#
# * Report the total number of crimes in the dataset.
# * List the various categories of crime. How many are there?
# * List the number of crimes in each category

# %% [markdown]
# First is to import the data from the .csv file

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

data = pd.read_csv("../Police_Department_Incident_Reports__Historical_2003_to_May_2018.csv")

data.head()
# Out:
#              PdId  IncidntNum  Incident Code       Category  \
# 0   4133422003074    41334220           3074        ROBBERY
# 1   5118535807021    51185358           7021  VEHICLE THEFT
# 2   4018830907021    40188309           7021  VEHICLE THEFT
# 3  11014543126030   110145431          26030          ARSON
# 4  10108108004134   101081080           4134        ASSAULT
#
#                 Descript DayOfWeek        Date   Time PdDistrict Resolution  \
# 0  ROBBERY, BODILY FORCE    Monday  11/22/2004  17:50  INGLESIDE       NONE
# 1      STOLEN AUTOMOBILE   Tuesday  10/18/2005  20:00       PARK       NONE
# 2      STOLEN AUTOMOBILE    Sunday  02/15/2004  02:00   SOUTHERN       NONE
# 3                  ARSON    Friday  02/18/2011  05:27  INGLESIDE       NONE
# 4                BATTERY    Sunday  11/21/2010  17:00   SOUTHERN       NONE
#
#    ... Fix It Zones as of 2017-11-06  2 2  DELETE - HSOC Zones 2 2  \
# 0  ...                                NaN                      NaN
# ...

# %%
# Count total number of crimes (computed as the total number of rows in the csv file) 

print("Total number of crimes: " + str(len(data.index)))
# Out:
# Total number of crimes: 2129525

# %%
# List and count the number of different crime categories
print("The number of crime categories: " + str(data["Category"].nunique()) + "\n")

print("The different crime categories: \n" + str(data["Category"].unique()))
# Out:
# The number of crime categories: 37
#
# The different crime categories:
# ['ROBBERY' 'VEHICLE THEFT' 'ARSON' 'ASSAULT' 'TRESPASS' 'BURGLARY'
#  'LARCENY/THEFT' 'WARRANTS' 'OTHER OFFENSES' 'DRUG/NARCOTIC'
#  'SUSPICIOUS OCC' 'LIQUOR LAWS' 'VANDALISM' 'WEAPON LAWS' 'NON-CRIMINAL'
#  'MISSING PERSON' 'FRAUD' 'SEX OFFENSES, FORCIBLE' 'SECONDARY CODES'
#  'DISORDERLY CONDUCT' 'RECOVERED VEHICLE' 'KIDNAPPING'
#  'FORGERY/COUNTERFEITING' 'PROSTITUTION' 'DRUNKENNESS' 'BAD CHECKS'
#  'DRIVING UNDER THE INFLUENCE' 'LOITERING' 'STOLEN PROPERTY' 'SUICIDE'
#  'BRIBERY' 'EXTORTION' 'EMBEZZLEMENT' 'GAMBLING' 'PORNOGRAPHY/OBSCENE MAT'
#  'SEX OFFENSES, NON FORCIBLE' 'TREA']

# %%
print("The number of crimes commited in each category: \n" + str(data.groupby(["Category"]).size()))
# Out:
# The number of crimes commited in each category:
# Category
# ARSON                            3875
# ASSAULT                        167042
# BAD CHECKS                        924
# BRIBERY                           796
# BURGLARY                        91067
# DISORDERLY CONDUCT               9932
# DRIVING UNDER THE INFLUENCE      5652
# DRUG/NARCOTIC                  117821
# DRUNKENNESS                      9760
# EMBEZZLEMENT                     2984
# EXTORTION                         729
# FORGERY/COUNTERFEITING          22995
# FRAUD                           41348
# GAMBLING                          343
# KIDNAPPING                       4282
# LARCENY/THEFT                  477975
# LIQUOR LAWS                      2840
# LOITERING                        2402
# MISSING PERSON                  44268
# NON-CRIMINAL                   236928
# OTHER OFFENSES                 301874
# PORNOGRAPHY/OBSCENE MAT            57
# PROSTITUTION                    16501
# ...

# %% [markdown]
# # Exercise 2
# * We have already counted the number of crimes in each category. What is the most commonly occurring category of crime? What is the least frequently occurring?
# * Create a bar-plot over crime occurrences. This is a data visualization class, so here is the first essential lesson: For a plot to be informative you need to label the axes (The police chief will be furious if you forget). It can also be nice to other relevant pieces of info, title, labels, etc.).

# %%
print("The number of crimes commited in each category in descending order: \n" + str(data['Category'].value_counts().sort_values(ascending=False)))
# Out:
# The number of crimes commited in each category in descending order:
# LARCENY/THEFT                  477975
# OTHER OFFENSES                 301874
# NON-CRIMINAL                   236928
# ASSAULT                        167042
# VEHICLE THEFT                  126228
# DRUG/NARCOTIC                  117821
# VANDALISM                      114718
# WARRANTS                        99821
# BURGLARY                        91067
# SUSPICIOUS OCC                  79087
# ROBBERY                         54467
# MISSING PERSON                  44268
# FRAUD                           41348
# FORGERY/COUNTERFEITING          22995
# SECONDARY CODES                 22378
# WEAPON LAWS                     21004
# TRESPASS                        19194
# PROSTITUTION                    16501
# STOLEN PROPERTY                 11450
# DISORDERLY CONDUCT               9932
# DRUNKENNESS                      9760
# SEX OFFENSES, FORCIBLE           8747
# RECOVERED VEHICLE                8688
# ...

# %%
plotData = data['Category'].value_counts().sort_values(ascending=False)

plotData.plot.bar()
plt.xticks(rotation=90, horizontalalignment="center")
plt.title("Occurences of each crime type")
plt.xlabel("Category")
plt.ylabel("Occurrences")
# Out:
# Text(0, 0.5, 'Occurrences')

# %% [markdown]
# # Exercise 3
# To start off easily, let's count the number of crimes per year:
# * What is the year with most crimes?
# * What is the year with the fewest crimes? (hint if your result is 2018, go back and see what I wrote about the date range).
#
# Create a barplot of crimes-per-year (years on the x-axis, crime-counts on the y-axis).
#
# Finally, Police chief Suneman is interested in the temporal development of only a subset of categories, the so-called *focus crimes*. Those categories are listed below (for convenient copy-paste action). Create bar-charts displaying the year-by-year development of each of these categories across the years 2003-2017.

# %%
# Making a subset of data for crimes committed each year (with 2018 removed, since the dataset stops in the middle of 2018)
data = data[data["Date"].str.contains("2018") == False]
data['Date'].str[-4:].value_counts().sort_values(ascending=False)
# Out:
# 2015    151459
# 2017    149487
# 2013    147664
# 2016    145994
# 2014    144844
# 2003    142803
# 2004    142054
# 2005    137048
# 2012    135464
# 2008    135242
# 2009    134309
# 2006    131856
# 2007    131771
# 2010    127758
# 2011    126713
# Name: Date, dtype: int64

# %%
data = data[data["Date"].str.contains("2018") == False]
plotData = data.groupby(data['Date'].str[-4:]).size()

plotData.plot.bar()

plt.xticks(rotation=45, horizontalalignment="center")
plt.title("Crimes committed per year")
plt.xlabel("Year")
plt.ylabel("Occurrences")
# Out:
# Text(0, 0.5, 'Occurrences')

# %%
focuscrimes = list(['WEAPON LAWS', 'PROSTITUTION', 'DRIVING UNDER THE INFLUENCE', 'ROBBERY', 'BURGLARY', 'ASSAULT', 'DRUNKENNESS', 'DRUG/NARCOTIC', 'TRESPASS', 'LARCENY/THEFT', 'VANDALISM', 'VEHICLE THEFT', 'STOLEN PROPERTY', 'DISORDERLY CONDUCT'])

data = data[data["Date"].str.contains("2018") == False]
dataCategoryYear = data.groupby(['Category', data['Date'].str[-4:]]).size()


np.arange(len(dataCategoryYear["PROSTITUTION"]))
dataCategoryYear["PROSTITUTION"]
# fig, axs = plt.subplots(7, 2, figsize=(30, 30))

# k = 0
# for i in range(7):
#     for j in range(2):
#         categoryName = focuscrimes[k]
#         axs[i,j].bar(np.arange(len(dataCategoryYear[categoryName])), dataCategoryYear[categoryName])
#         axs[i,j].set_title(categoryName)
#         axs[i,j].set_xticks(np.arange(len(dataCategoryYear[categoryName])))
#         axs[i,j].set_xticklabels(range(2003,2018))
#         axs[i,j].set_ylabel("Occurrences")
#         if i == 6:
#             axs[i,j].set_xlabel("Year")
#         k += 1

        
# # Show the plot    
# plt.suptitle('Crimes comitted pr year by category')
# plt.subplots_adjust(wspace=0.4,
#                     hspace=0.4)
# plt.show()
# Out:
# Date
# 2003    1937
# 2004    1505
# 2005    1088
# 2006    1264
# 2007    1848
# 2008    1662
# 2009    1457
# 2010    1281
# 2011    1078
# 2012     678
# 2013     678
# 2014     449
# 2015     370
# 2016     635
# 2017     523
# dtype: int64
